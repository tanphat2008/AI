# %% [markdown]
# <a href="https://colab.research.google.com/github/tanphat2008/AI/blob/main/AI_31_3_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import mnist
(train_images,train_labels),(test_images,test_labels)=mnist.load_data()
x=test_images
y=test_labels

# %%
import matplotlib.pyplot as plt
digit= train_images[200]
plt.imshow(digit,cmap= plt.cm.binary)
plt.show()
print('so nay la:',train_labels[200])
# Out:
# so nay la: 1

# %%
for i in range(25):
  plt.subplot(5,5,i+1)
  plt.tight_layout()
  plt.imshow(train_images[i],cmap='gray',interpolation='none')
  plt.title('so:{}' .format(train_labels[i]))
  plt.xticks([])
  plt.yticks([])

# %%
from keras.models import Sequential
from keras.layers import Dense 
model=Sequential()
model.add(Dense(512,activation='relu',input_shape= (784,)))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_8 (Dense)             (None, 512)               401920
#
#  dense_9 (Dense)             (None, 10)                5130
#
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_images=train_images.reshape(60000,28*28)
train_images=train_images.astype('float32')/255
test_images=test_images.reshape(10000,28*28)
test_images=test_images.astype('float32')/255

# %%
from keras.utils import to_categorical
train_labels= to_categorical(train_labels,10)
test_labels=to_categorical(test_labels,10)

# %%
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(train_images,train_labels,epochs=10,batch_size=128)
test_loss,test_acc=model.evaluate(test_images,test_labels)
print('mat mat',test_loss)
print('do chinh xac',test_acc)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2616 - accuracy: 0.9243
# Epoch 2/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1076 - accuracy: 0.9679
# Epoch 3/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0710 - accuracy: 0.9790
# Epoch 4/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0516 - accuracy: 0.9846
# Epoch 5/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0392 - accuracy: 0.9882
# Epoch 6/10
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0295 - accuracy: 0.9911
# Epoch 7/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0226 - accuracy: 0.9938
# Epoch 8/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0178 - accuracy: 0.9950
# Epoch 9/10
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0127 - accuracy: 0.9967
# Epoch 10/10
# ...

# %%
img=x[9]

# %%
plt.imshow(img)
plt.show()
print(y[9])
# Out:
# 9

# %%
x_pred=x[9].reshape(1,28*28)

# %%
x_pred=x_pred.astype('float32')/255

# %%
import numpy as np
np.argmax(model.predict(x_pred),axis=-1)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# array([9])
